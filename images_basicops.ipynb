# %% [markdown]
# <a href="https://colab.research.google.com/github/alexlinapp/python_tools_practice/blob/main/images_basicops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
from google.colab import files
from google.colab.patches import cv2_imshow

# %%
uploaded = files.upload();
# Out:
#      <input type="file" id="files-458efb1f-9e95-405c-bb8f-703ac9c7eadd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-458efb1f-9e95-405c-bb8f-703ac9c7eadd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv.imread("dinoGameHighScore.png")
assert img is not None, "Failed to open file"
# cv2_imshow(img)
px = img[100, 100]
print(px)
for i in range(100):
  for j in range(100):
    img[i, j] = [0, 0, 255]
cv2_imshow(img)
print(img.shape)
print(img.dtype)
print("Github!")

dino = img[300:600, 0:200]
# cv2_imshow(dino)
img[50:350, 500:700] = dino
cv2_imshow(img)
# Out:
# [255 255 255]
# <PIL.Image.Image image mode=RGB size=1837x747>
# (747, 1837, 3)
# uint8
# Github!
# <PIL.Image.Image image mode=RGB size=1837x747>
